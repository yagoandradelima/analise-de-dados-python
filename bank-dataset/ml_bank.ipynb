# %%
import plotly.express as px
import pandas as pd

treino_clientes = pd.read_csv('train.csv')
teste_clientes = pd.read_csv('test.csv')

X_treino_clientes = treino_clientes[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']]

y_treino_clientes = treino_clientes.Exited

X_teste_clientes = teste_clientes[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']]

y_teste_clientes = treino_clientes.Exited

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(random_state=1)

clf.fit(X_treino_clientes, y_treino_clientes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 from sklearn.ensemble import RandomForestRegressor
#       3 clf = RandomForestRegressor(random_state=1)
# ----> 5 clf.fit(X_treino_clientes, y_treino_clientes)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
# ...
